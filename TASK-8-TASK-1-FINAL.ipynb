# %%
import pandas as pd

# %%
df=pd.read_csv('English.csv')

# %%
df.head(100
       )
# Out:
#    English words/sentences
# 0                      Hi.
# 1                     Run!
# 2                     Run!
# 3                     Who?
# 4                     Wow!
# ..                     ...
# 95                Call us.
# 96                Call us.
# 97                Come in.
# 98                Come in.
# 99                Come in.
#
# [100 rows x 1 columns]

# %%
df.size
# Out:
# 175621

# %%
from translate import Translator

# %%
to_Spanish=Translator(to_lang='Spanish')

# %%
to_german=Translator(to_lang='German')

# %%
to_french=Translator(to_lang='French')

# %%
df2=df.head(20)

# %%
df2['German']=df2['English words/sentences'].apply(lambda x:trans_german(x))
# Out:
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16524\2914069431.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['German']=df2['English words/sentences'].apply(lambda x:trans_german(x))

# %%
df2
# Out:
#    English words/sentences                      German
# 0                      Hi.                      Hallo,
# 1                     Run!                       Lauf!
# 2                     Run!                       Lauf!
# 3                     Who?                     Welche?
# 4                     Wow!                        Wow!
# 5                    Fire!                      Feuer!
# 6                    Help!                      Hilfe!
# 7                    Jump.  Mit einem Fingerschnippen.
# 8                    Stop!                       Stop!
# 9                    Stop!                       Stop!
# 10                   Stop!                       Stop!
# 11                   Wait!                 Warten Sie!
# 12                   Wait!                 Warten Sie!
# 13                  Go on.               Los begonnen.
# 14                  Go on.               Los begonnen.
# 15                  Go on.            Weiter begonnen.
# ...

# %%
##df2['German']=df2['English words/sentences'].apply(lambda x:trans_german(x))

# %%
def trans_german(str1):
    c=str1.split()
    trans_ls=[]
    for i in range (len(c)):
        trans_ls.append(to_german.translate(c[i]))
        res_g=' '.join(trans_ls)
    return res_g

# %%
def trans_spanish(str1):
    c=str1.split()
    trans_ls=[]
    for i in range (len(c)):
        trans_ls.append(to_Spanish.translate(c[i]))
        res_g=' '.join(trans_ls)
    return res_g

# %%
def trans_french(str1):
    c=str1.split()
    trans_ls=[]
    for i in range (len(c)):
        trans_ls.append(to_french.translate(c[i]))
        res_g=' '.join(trans_ls)
    return res_g

# %%
df2['Spanish']=df2['English words/sentences'].apply(lambda x:trans_spanish(x))
# Out:
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16524\126807080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Spanish']=df2['English words/sentences'].apply(lambda x:trans_spanish(x))

# %%
df2['French']=df2['English words/sentences'].apply(lambda x:trans_french(x))
# Out:
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16524\1595948512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['French']=df2['English words/sentences'].apply(lambda x:trans_french(x))

# %%
df2
# Out:
#    English words/sentences                      German         Spanish  \
# 0                      Hi.                      Hallo,            hola
# 1                     Run!                       Lauf!         ¡Corre!
# 2                     Run!                       Lauf!         ¡Corre!
# 3                     Who?                     Welche?         ¿Quién?
# 4                     Wow!                        Wow!     ¡Qué dices!
# 5                    Fire!                      Feuer!         ¡Fuego!
# 6                    Help!                      Hilfe!       ¡Socorro!
# 7                    Jump.  Mit einem Fingerschnippen.          Salta.
# 8                    Stop!                       Stop!         ¡Paren!
# 9                    Stop!                       Stop!         ¡Paren!
# 10                   Stop!                       Stop!         ¡Paren!
# 11                   Wait!                 Warten Sie!        ¡Espera!
# ...
